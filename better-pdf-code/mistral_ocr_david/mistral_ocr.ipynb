# %%
from mistralai import Mistral
import datauri
import os

api_key = os.environ["MISTRAL_API_KEY"]
client = Mistral(api_key=api_key)

# %%
def ocr_from_link(link):
    return client.ocr.process(
        model="mistral-ocr-latest",
        document={
        "type": "document_url",
        "document_url": link,
        },
    )

def upload_pdf(filename):
  uploaded_pdf = client.files.upload(
    file={
      "file_name": filename,
      "content": open(filename, "rb"),
    },
    purpose="ocr"
  )
  signed_url = client.files.get_signed_url(file_id=uploaded_pdf.id)
  return signed_url.url

def create_markdown_file(ocr_response, output_filename = "output.md"):
  with open(output_filename, "wt") as f:
    for page in ocr_response.pages:
      f.write(page.markdown)
      for image in page.images:
        save_image(image)

# %%
link = upload_pdf("data/SGD_19081909_0000214.pdf")
print(f"link: {link}")
ocr_response = ocr_from_link(link)
print(ocr_response)
create_markdown_file(ocr_response=ocr_response, output_filename= "data/19081909_historical_tweede_kammer.pdf")
# Out:
# link: https://mistralaifilesapiprodswe.blob.core.windows.net/fine-tune/539e14bf-4f56-4115-8d00-b771c061dc67/2c410eddcab945969948378d73f73f7c.pdf?se=2025-03-16T14%3A18%3A04Z&sp=r&sv=2025-01-05&sr=b&sig=aPih3YuXtri1/7FXnouSdTC3XtvV2w59gdrYkO9erGM%3D
# pages=[OCRPageObject(index=0, markdown="# 44ste VERGADERING. \n\nVERGADERING VAN MAANDAG 14 DECEMBER 1908.\n(GEOPEND TE I ${ }^{1}$, UCK.)\n\nVerklaring van een lid naar aanleiding van de notulen. Ingekomen: $1^{\\circ}$. berichten van leden; 2 . een wetsontwerp: $3^{\\circ}$. en $4^{0}$. verzoekschriften; $5^{0}$. een schrijven; $6^{\\circ}$. drukwerken. - Verslag uitgebracht over een wetsontwerp. - Regeling van werkzaamheden. - Behandeling van de Staatsbegrooting voor 1909; aanvang van de beraadslaging over hoofdstuk VIII. - A rondvergadering. Nog ingekomen: een bericht van een lid. - Voorizetting van de beraadslaging over hoofdstuk VIII. - Verslag uitgebracht over een wetsontwerp.\n\n## Voorzitter: de heer Hõrli.\n\nTegenwoordig, met den Voorzitter, 74 leden, te weten de neeren :\n\nSmidt, Plate, van Citters, Jansen (den Haag), van Doorn, Drucker, Goeman Borgesius, Nolens, van Voon, van de Velde, IJzerman, de Savornin Lohman, de Ram, van der Voort van Zijp, van Vliet, Jannink, Rosdhuyzen, van Bylandt, Arts, Treub, Passtoors, Reyne, Regout, van den Berch van Heemstede, Lely, Bogaardt, Limburg, de Geer, van Idsinga, Hennequin, Thomson, ter Laan, Loeff, Mees, Duymser van Twist, Ferf, Lieftinek, de Visser, Roessingh, van Hoemstra, de Waal Malefijt, Aalberse, Ketelaar, Helsdingen, van Deventer, van Styrum, Dolk, van Foreest, Marchant, Bloeker, Patijn, Eland, Koolen, van Kol, van Nispen tot Sevenaer (Nijnsegen), de Stuers, Schaper, Verhey, Hubrecht, Tydeman, Troelstra, van Asch van Wijck, van Dedem, Brommelkamp, de Boer, Nolting, van Nispen tot Sevenaer (Rheden), Fraytier, Smeenge, Ruys de Beerenbroock, Zijlma, Hugenholtz en van Vuuren.\nen de heeren Ministers van Binnenlandsche Zaken en van Oorlog.\n\nDe notulen van het verhandelde in de vorige vergadering worden gelezen.\n\nDe Voorzitter: Ik geef het woord aan den heer van Deventer, die het mij naar aanleiding van de notulen gevraagd heeft.\n\nDe heer van Deventer: Mijnheer de Voorzitter! Het is niet mijn bedoeling aanmerkingen te maken op de voorgelezen notulen van de vergadering van verleden Vrijdag, die als gewoonlijk zeer nauwkeurig zijn, naar alleen om van deze gelegenheid gebruik te maken, uitdrukkelijk te verklaren, dat ik mij in die zitting bij het nithrengen van mijn stem over het amendement van den heer Hugenholtz, in een oogenblik van door mij zeer betreurde verstrooidheid, vergist heb. Het was niet mijn bedoeling om, zoials ik gedaan heb, vóór dat amendement te stemmen, integendeel, mijn bedoeling was daar tegen te stemmen.\n\nDe Voorzitter: Overeenkomstig hetgeen hij vorige gelegenheden is geschied, stel ik aan de Vergadering voor, dat van deze verklaring van den heer van Deventer in de notulen aanteekening zal gehouden worden.\n\nDaartoe wordt besloten.\nDe notulen worden goedgekeurd.\nDe Voorzitter: Ik deel aan de Vergadering mede:\nA. dat zijn ingekomen:\n$1^{\\circ}$. berichten van leden die verhinderd zijn de vergadering hij te wonen: van den heer Schokking, wegens ambtsbezigheden; van de heeren van Wijnbergen en van Gijn, de laatste wellicht ook morgen.\n\nDeze berichten worden voor kennisgeving aangenomen:\n$2^{\\circ}$. een Koninklijke boodschap, ten geleide van een ontwerp van wet tot vaststelling van de begrooting van uitgaven van het Funds voor de uitvoering van de Tiendwet 1907 (Staatsblad $n^{\\circ}$. 222), voor het dienstjaar 1909.\n\nDit wetsontwerp, dat met de daarbij behoorende stukken reeds is gedrukt en rondgedeeld, zal worden gezondens aan de afdeelingen;\n$3^{\\circ}$. de volgende verzoekschriften:\ntwee, betreffende de maatregelen te nemen in het belang der gemeenten in Zuid-Limburg in verbaind met de exploitatie der steenkolonnijnen in die streek, van de gemeenteraden van Roosteren en van Born:\neen, van M. H. E. Bremer, Iste-voorzitter, en 6 anderen, namecs den Bond van Klerken bij de Rijksverzekeringsbank, ontrent het examen ingesteld voor den rang van adjunct-commies bij de Rijksverzekeringsbank en periodieke traktementsverhooging voor de ...

# %% [markdown]
# # Formating
#
# The speech of a person is characterised by (new paragraph) de heer [name]: text in direct speech new paragraph
#
# There are marker texts:
# - De beraadslaging wordt verdaagd.
# - De vergadering wordt gesloten.
#
# Text interrupt
# - "# 4-digit number or "Vel"  + markdown title
